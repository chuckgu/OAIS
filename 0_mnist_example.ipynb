# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

tf.scalar_summary("accuracy", accuracy)
tf.scalar_summary("cost", cost)

merged = tf.merge_all_summaries()

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    writer = tf.train.SummaryWriter("mnist_logs",graph=tf.get_default_graph())
    
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
            #summary_str = sess.run(merged)
            #writer.add_summary(summary_str, step)
        step += 1
    print "Optimization Finished!"
    
    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 25034.824219, Training Accuracy= 0.30469
# Iter 2560, Minibatch Loss= 15815.398438, Training Accuracy= 0.34375
# Iter 3840, Minibatch Loss= 9693.947266, Training Accuracy= 0.57031
# Iter 5120, Minibatch Loss= 4362.846680, Training Accuracy= 0.74219
# Iter 6400, Minibatch Loss= 6579.133301, Training Accuracy= 0.64844
# Iter 7680, Minibatch Loss= 2313.214844, Training Accuracy= 0.79688
# Iter 8960, Minibatch Loss= 3218.995850, Training Accuracy= 0.77344
# Iter 10240, Minibatch Loss= 1353.636719, Training Accuracy= 0.92188
# Iter 11520, Minibatch Loss= 4002.833496, Training Accuracy= 0.76562
# Iter 12800, Minibatch Loss= 846.865601, Training Accuracy= 0.89844
# Iter 14080, Minibatch Loss= 1229.976074, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 1842.203735, Training Accuracy= 0.87500
# Iter 16640, Minibatch Loss= 1618.559814, Training Accuracy= 0.89062
# Iter 17920, Minibatch Loss= 1190.683838, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 388.004517, Training Accuracy= 0.94531
# Iter 20480, Minibatch Loss= 3655.318848, Training Accuracy= 0.82812
# Iter 21760, Minibatch Loss= 664.048706, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1536.489014, Training Accuracy= 0.87500
# Iter 24320, Minibatch Loss= 1654.305786, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 443.777710, Training Accuracy= 0.93750
# Iter 26880, Minibatch Loss= 1171.731201, Training Accuracy= 0.90625
# Iter 28160, Minibatch Loss= 1370.714600, Training Accuracy= 0.89844
# Iter 29440, Minibatch Loss= 508.241760, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 1237.393555, Training Accuracy= 0.92969
# Iter 32000, Minibatch Loss= 1541.237061, Training Accuracy= 0.88281
# Iter 33280, Minibatch Loss= 435.680420, Training Accuracy= 0.95312
# Iter 34560, Minibatch Loss= 704.825500, Training Accuracy= 0.95312
# Iter 35840, Minibatch Loss= 1232.057129, Training Accuracy= 0.92188
# Iter 37120, Minibatch Loss= 223.849670, Training Accuracy= 0.95312
# Iter 38400, Minibatch Loss= 149.488464, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 1643.376465, Training Accuracy= 0.90625
# Iter 40960, Minibatch Loss= 1521.166504, Training Accuracy= 0.92188
# Iter 42240, Minibatch Loss= 437.722565, Training Accuracy= 0.97656
# Iter 43520, Minibatch Loss= 655.202515, Training Accuracy= 0.96875
# Iter 44800, Minibatch Loss= 79.487427, Training Accuracy= 0.98438
# Iter 46080, Minibatch Loss= 925.020996, Training Accuracy= 0.92188
# Iter 47360, Minibatch Loss= 1748.470825, Training Accuracy= 0.90625
# Iter 48640, Minibatch Loss= 742.297119, Training Accuracy= 0.92188
# Iter 49920, Minibatch Loss= 484.358582, Training Accuracy= 0.96094
# Iter 51200, Minibatch Loss= 400.315125, Training Accuracy= 0.96094
# Iter 52480, Minibatch Loss= 67.514008, Training Accuracy= 0.99219
# Iter 53760, Minibatch Loss= 532.123840, Training Accuracy= 0.93750
# Iter 55040, Minibatch Loss= 1285.619873, Training Accuracy= 0.90625
# Iter 56320, Minibatch Loss= 711.555664, Training Accuracy= 0.93750
# Iter 57600, Minibatch Loss= 726.291260, Training Accuracy= 0.91406
# Iter 58880, Minibatch Loss= 426.043091, Training Accuracy= 0.96875
# Iter 60160, Minibatch Loss= 727.405212, Training Accuracy= 0.96094
# Iter 61440, Minibatch Loss= 793.826355, Training Accuracy= 0.92188
# Iter 62720, Minibatch Loss= 1125.000244, Training Accuracy= 0.90625
# Iter 64000, Minibatch Loss= 798.623047, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 406.164856, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 129.568893, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 444.704895, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 721.991089, Training Accuracy= 0.92969
# Iter 70400, Minibatch Loss= 623.129761, Training Accuracy= 0.92188
# Iter 71680, Minibatch Loss= 494.070251, Training Accuracy= 0.92969
# Iter 72960, Minibatch Loss= 436.754425, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 406.726074, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 407.737885, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 442.623260, Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 722.524109, Training Accuracy= 0.93750
# Iter 79360, Minibatch Loss= 429.832458, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 302.697693, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 301.669281, Training Accuracy= 0.95312
# Iter 83200, Minibatch Loss= 158.554596, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 418.531677, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 247.972046, Training Accuracy= 0.95312
# Iter 87040, Minibatch Loss= 663.327271, Training Accuracy= 0.90625
# Iter 88320, Minibatch Loss= 501.924011, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 1110.913330, Training Accuracy= 0.93750
# Iter 90880, Minibatch Loss= 181.949188, Training Accuracy= 0.96875
# Iter 92160, Minibatch Loss= 388.197449, Training Accuracy= 0.95312
# Iter 93440, Minibatch Loss= 231.838394, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 401.343628, Training Accuracy= 0.94531
# Iter 96000, Minibatch Loss= 182.870682, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 720.833069, Training Accuracy= 0.94531
# Iter 98560, Minibatch Loss= 689.879700, Training Accuracy= 0.94531
# Iter 99840, Minibatch Loss= 784.398743, Training Accuracy= 0.92188
# Iter 101120, Minibatch Loss= 901.056213, Training Accuracy= 0.91406
# Iter 102400, Minibatch Loss= 638.163757, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 1103.505737, Training Accuracy= 0.91406
# Iter 104960, Minibatch Loss= 554.867920, Training Accuracy= 0.96094
# Iter 106240, Minibatch Loss= 178.081116, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 173.345306, Training Accuracy= 0.97656
# Iter 108800, Minibatch Loss= 34.425858, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 10.804245, Training Accuracy= 0.99219
# Iter 111360, Minibatch Loss= 438.340942, Training Accuracy= 0.93750
# Iter 112640, Minibatch Loss= 107.979195, Training Accuracy= 0.98438
# Iter 113920, Minibatch Loss= 80.162010, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 441.870667, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 403.280975, Training Accuracy= 0.95312
# Iter 117760, Minibatch Loss= 372.759796, Training Accuracy= 0.96094
# Iter 119040, Minibatch Loss= 181.845673, Training Accuracy= 0.96094
# Iter 120320, Minibatch Loss= 86.535233, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 300.945282, Training Accuracy= 0.96094
# Iter 122880, Minibatch Loss= 402.343018, Training Accuracy= 0.95312
# Iter 124160, Minibatch Loss= 339.413330, Training Accuracy= 0.95312
# Iter 125440, Minibatch Loss= 651.606628, Training Accuracy= 0.92969
# Iter 126720, Minibatch Loss= 252.561310, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 122.778427, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 306.535522, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 107.190758, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 242.315613, Training Accuracy= 0.99219
# Iter 133120, Minibatch Loss= 345.087952, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 239.642746, Training Accuracy= 0.96094
# Iter 135680, Minibatch Loss= 202.548492, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 399.710266, Training Accuracy= 0.96094
# Iter 138240, Minibatch Loss= 354.043579, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 144.575546, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 183.008362, Training Accuracy= 0.95312
# Iter 142080, Minibatch Loss= 13.719589, Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 204.184189, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 401.743103, Training Accuracy= 0.95312
# Iter 145920, Minibatch Loss= 112.914459, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 364.744873, Training Accuracy= 0.96875
# Iter 148480, Minibatch Loss= 400.644348, Training Accuracy= 0.94531
# Iter 149760, Minibatch Loss= 58.863869, Training Accuracy= 0.98438
# Iter 151040, Minibatch Loss= 309.675171, Training Accuracy= 0.94531
# Iter 152320, Minibatch Loss= 394.150482, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 127.753998, Training Accuracy= 0.96094
# Iter 154880, Minibatch Loss= 392.189819, Training Accuracy= 0.94531
# Iter 156160, Minibatch Loss= 738.821167, Training Accuracy= 0.92969
# Iter 157440, Minibatch Loss= 405.728546, Training Accuracy= 0.95312
# Iter 158720, Minibatch Loss= 110.378021, Training Accuracy= 0.97656
# Iter 160000, Minibatch Loss= 95.202835, Training Accuracy= 0.99219
# Iter 161280, Minibatch Loss= 17.173149, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 112.614975, Training Accuracy= 0.99219
# Iter 163840, Minibatch Loss= 122.501999, Training Accuracy= 0.97656
# Iter 165120, Minibatch Loss= 204.730865, Training Accuracy= 0.97656
# Iter 166400, Minibatch Loss= 604.460571, Training Accuracy= 0.94531
# Iter 167680, Minibatch Loss= 413.168030, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 31.507202, Training Accuracy= 0.97656
# Iter 170240, Minibatch Loss= 160.684479, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 153.320801, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 252.687668, Training Accuracy= 0.94531
# Iter 174080, Minibatch Loss= 208.591614, Training Accuracy= 0.96094
# Iter 175360, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 176640, Minibatch Loss= 264.522736, Training Accuracy= 0.94531
# Iter 177920, Minibatch Loss= 111.255737, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 286.645996, Training Accuracy= 0.96875
# Iter 180480, Minibatch Loss= 26.245872, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 170.354446, Training Accuracy= 0.96094
# Iter 183040, Minibatch Loss= 21.054756, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 130.594589, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 131.382065, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 132.266205, Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 71.022537, Training Accuracy= 0.98438
# Iter 189440, Minibatch Loss= 3.095131, Training Accuracy= 0.99219
# Iter 190720, Minibatch Loss= 285.466888, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 195.712616, Training Accuracy= 0.93750
# Iter 193280, Minibatch Loss= 82.512215, Training Accuracy= 0.96875
# Iter 194560, Minibatch Loss= 228.701508, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 270.666077, Training Accuracy= 0.96094
# Iter 197120, Minibatch Loss= 70.048111, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 107.654533, Training Accuracy= 0.97656
# Iter 199680, Minibatch Loss= 140.779526, Training Accuracy= 0.96094
# Optimization Finished!
# Testing Accuracy: 0.984375
